# %%
import matplotlib.pyplot as plt
import io
import pandas as pd
x=[
9.711307073,
0.7956544127,
1.866425874,
6.070416584,
0.04306186361,
7.127298511,
8.474656913,
2.712239848,
4.982193571,
6.008536341,
7.157298671,
8.680544956,
6.631189149,
5.879336292,
6.616682719,
1.146765466,
3.427339736,
2.568570141,
6.337365982,
4.237250255
]
y=[
22.42261415,
4.591308825,
6.732851747,
15.14083317,
3.086123727,
17.25459702,
19.94931383,
8.424479695,
12.96438714,
15.01707268,
17.31459734,
20.36108991,
16.2623783,
14.75867258,
16.23336544,
5.293530932,
9.854679472,
8.137140282,
15.67473196,
11.47450051
]
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import io
import pandas as pd
import numpy as np
x=np.array( [
2.254235614,
7.502592373,
2.7133517,
9.77452046,
6.868457725,
7.998949532,
6.82279956,
5.080419862,
6.320125937,
5.641808831,
9.647420926,
4.833828725,
6.818462161,
8.984591741,
3.473591965,
3.390873174,
9.340974918,
9.907476389,
9.578590379,
0.1375056881
] )
y=np.array( [
1.378475153,
19.54178666,
4.356272581,
26.5716189,
14.60446541,
20.57696067,
17.63283101,
11.21315166,
13.81481571,
9.934975248,
25.98258652,
11.36386745,
16.48987672,
22.7417226,
7.707193976,
4.526956387,
21.78839736,
25.58939317,
23.96109,
-6.699647042,
] )
plt.scatter(x,y)
plt.show()

# %%
x=x.reshape(-1,1)
y=y.reshape(-1,1)
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
plt.scatter(x,y)
lr.fit(x,y)
plt.plot([0,10],[lr.intercept_,10*lr.coef_[0]+lr.intercept_])
plt.show()

# %%
import io
import pandas as pd

data = pd.read_csv(io.StringIO('''
2.254235614,1.378475153
7.502592373,19.54178666
2.7133517,4.356272581
9.774520461,26.5716189
6.868457725,14.60446541
7.998949532,20.57696067
6.82279956,17.63283101
5.080419862,11.21315166
6.320125937,13.81481571
5.641808831,9.934975248
9.647420926,25.98258652
4.833828725,11.36386745
6.818462161,16.48987672
8.984591741,22.7417226
3.473591965,7.707193976
3.390873174,4.526956387
9.340974918,21.78839736
9.907476389,25.58939317
9.578590379,23.96109
0.1375056881,-6.699647042
'''), header=None)
import matplotlib.pyplot as plt

x = data[0].tolist()
y = data[1].tolist()

plt.scatter(x, y)
plt.show()
import numpy as np

order = 1  # 몇차 함수 사용할지에 대한 숫자
mymodel = np.poly1d(np.polyfit(x, y, order))  # 회귀 문제를 알아서 풀어줌!

# 우리가 찾은 모델을 그려보자
myline = np.linspace(0, 10, 100)
plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()

# %%
x=np.array([
0.3677471741,
4.2733599,
8.387553189,
1.391683427,
2.733872382,
6.534866539,
0.1752605833,
2.247364631,
5.462769513,
2.759016937,
4.310732048,
7.6790348,
7.6245414,
2.368853821,
5.835081626,
0.9767078323,
2.65940286,
3.851685941,
1.119541716,
1.351089319,
])
y=np.array([
23.9495801,
-0.7938753154,
39.89007558,
11.76299792,
2.037518095,
14.08768615,
27.29737539,
7.426860328,
5.770617785,
0.007987287039,
-2.081891787,
23.88869595,
24.93691355,
4.005807031,
3.353638038,
19.71096175,
2.736772067,
-3.312738236,
15.04988716,
12.4071713,
])
plt.scatter(x,y)
order=2
mymodel = np.poly1d(np.polyfit(x, y, order))  # 회귀 문제를 알아서 풀어줌!

# 우리가 찾은 모델을 그려보자
myline = np.linspace(0, 10, 100)
plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()

# %%
import io
import pandas as pd
data=pd.read_csv(io.StringIO('''
0.3677471741,23.9495801
4.2733599,-0.7938753154
8.387553189,39.89007558
1.391683427,11.76299792
2.733872382,2.037518095
6.534866539,14.08768615
0.1752605833,27.29737539
2.247364631,7.426860328
5.462769513,5.770617785
2.759016937,0.007987287039
4.310732048,-2.081891787
7.6790348,23.88869595
7.6245414,24.93691355
2.368853821,4.005807031
5.835081626,3.353638038
0.9767078323,19.71096175
2.65940286,2.736772067
3.851685941,-3.312738236
1.119541716,15.04988716
1.351089319,12.4071713
'''), header=None)
x = np.array(data[0].tolist())
y = np.array(data[1].tolist())
plt.scatter(x, y)
order=2
mymodel = np.poly1d(np.polyfit(x, y, order))  # 회귀 문제를 알아서 풀어줌!

# 우리가 찾은 모델을 그려보자
myline = np.linspace(0, 10, 100)

plt.plot(myline, mymodel(myline))
plt.show()

# %%
import io
import pandas as pd
data=pd.read_csv(io.StringIO('''
6.31092322,-788.5906241
0.2615387982,131.4806758
5.721030058,-922.0790779
4.305020965,-819.351237
4.680879335,-885.1848501
8.210679163,1094.038681
9.045159503,2957.501041
4.554761244,-869.5202966
6.999446255,-403.0223229
1.155767884,-18.63314185
8.992508766,2816.679667
8.304896844,1260.896473
8.725437557,2144.0493
9.618038045,4752.819575
0.2599601699,130.0672439
2.707106154,-384.0265016
3.352868619,-566.8070671
9.629679521,4789.760493
2.660359452,-379.0922637
2.842091309,-425.7116168
'''), header=None)
x = np.array(data[0].tolist())
y = np.array(data[1].tolist())
plt.scatter(x,y)
order=3
mymodel = np.poly1d(np.polyfit(x, y, order))  # 회귀 문제를 알아서 풀어줌!

# 우리가 찾은 모델을 그려보자
myline = np.linspace(0, 15, 100)

plt.plot(myline, mymodel(myline))
plt.show()

# %%
import io
import pandas as pd
data=pd.read_csv(io.StringIO('''
1.805204579,-0.8811019498
7.571074113,5.387225985
0.9642882978,0.5901447453
4.997130013,2.942112237
3.331671862,8.33491152
3.998603067,10.26311668
5.4634442,2.2629379
0.4951485043,4.392162058
1.602891775,0.2943116553
6.070169089,10.60924472
3.759625035,9.81702812
1.398794243,1.356956256
5.928701377,8.09806124
8.708318568,2.525776352
3.248394405,13.07787521
6.666429619,23.10203806
9.653472427,32.25536792
1.74048082,2.458725024
4.304523141,8.74740474
8.65417685,2.622236263
1.053997577,6.079482873
9.642959872,30.23239839
9.893528629,25.43330227
4.739033975,-1.980310838
0.8181986251,4.385119816
9.170448732,16.73522506
0.1015859818,-3.866853089
6.411406533,21.04522846
5.516578802,6.418061069
7.654573512,8.937492474
9.633438586,30.30237671
8.0785699,5.224242238
0.7068647832,4.66700904
3.749120514,14.55735112
5.712690727,6.851156209
8.220972226,-0.9335997267
4.353294887,8.268371746
6.706229084,21.71115907
1.016137448,-0.109746012
6.256171531,10.91137968
1.095524935,6.292441122
9.886987687,28.79928001
1.283549617,3.323987177
9.490597693,20.80802145
0.5681422143,3.720551671
9.141498538,14.27672817
0.06659770109,1.761350789
5.877215152,3.854083054
8.450291881,-4.255861028
6.937625245,20.10153208
3.715365204,6.25850562
9.947560771,28.62920172
7.215935577,18.69426316
8.674273345,1.936933484
8.148165317,2.778089489
1.249509374,3.258618828
4.658776402,4.782581924
8.484200054,-2.80485951
5.210143341,3.588198834
6.89752387,24.2604971
2.181905416,0.2793187056
8.012980462,6.225373647
0.498411419,4.301790924
2.430027916,5.240461196
1.570731027,-3.340967577
3.154910964,5.349004264
6.416225925,18.41588941
8.068933123,4.406317651
8.508779377,-0.8404316012
0.5332595391,-1.537862028
'''), header=None)

x = np.array(data[0].tolist())
y = np.array(data[1].tolist())
plt.scatter(x,y)
order=10

mymodel = np.poly1d(np.polyfit(x, y, order))  # 회귀 문제를 알아서 풀어줌!

# 우리가 찾은 모델을 그려보자
myline = np.linspace(0, 10, 100)

plt.plot(myline, mymodel(myline))
plt.show()
